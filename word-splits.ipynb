# %%
from tokenizer import LinearTokenizer
import tiktoken
import json
import pandas as pd

# %%
def upper_first(text):
    return text[0].upper() + (text[1:] if len(text) > 1 else "")


with open('./vocab.json', 'r', encoding='utf-8') as f:
    vocab = json.load(f)

tokenizer_lin = LinearTokenizer(vocab)
tokenizer_bpe = tiktoken.get_encoding("gpt2")

words = []
words.extend(['machine', 'machines', 'machined', 'machining', 'machinion',  'machinery', 'machineries'])
words.extend(['token', 'tokens', 'tokenized', 'tokenizing', 'tokenization', 'tokenizations', 'tokenset', 'tokensets', 'tokenism', 'tokenless', "tokenes", "detokenize"])
words.extend(['query', 'querying', 'queries', 'queryable', 'queried'])
words.extend(['container', 'containers'])
words.extend(['throttle', 'throttling', 'throttles', 'throttleable', 'throttled'])
words.extend(['transformer', 'transformers', 'transforming', 'transformable', 'transformation', 'pretransformer'])


def encode_word(word):
    ids_lin, tokens_lin = tokenizer_lin.encode(word, return_token_tuple=True)
    ids_bpe = tokenizer_bpe.encode(word)
    tokens_bpe = [tokenizer_bpe.decode([id]) for id in ids_bpe]
    return tokens_lin, tokens_bpe


data = {'words': words, 'bpe': [], 'lin': [], 'BPE': [], 'LIN': []}
for word in words:
    tokens_lin, tokens_bpe = encode_word(word)
    data['lin'].append(", ".join(tokens_lin))
    data['bpe'].append(", ".join(tokens_bpe))

    tokens_lin, tokens_bpe = encode_word(upper_first(word))
    data['LIN'].append(", ".join(tokens_lin))
    data['BPE'].append(", ".join(tokens_bpe))


df = pd.DataFrame(data)
df = df.style.set_properties(**{'text-align': 'left'})
df
# Out:
# <style type="text/css">
# #T_7a69b_row0_col0, #T_7a69b_row0_col1, #T_7a69b_row0_col2, #T_7a69b_row0_col3, #T_7a69b_row0_col4, #T_7a69b_row1_col0, #T_7a69b_row1_col1, #T_7a69b_row1_col2, #T_7a69b_row1_col3, #T_7a69b_row1_col4, #T_7a69b_row2_col0, #T_7a69b_row2_col1, #T_7a69b_row2_col2, #T_7a69b_row2_col3, #T_7a69b_row2_col4, #T_7a69b_row3_col0, #T_7a69b_row3_col1, #T_7a69b_row3_col2, #T_7a69b_row3_col3, #T_7a69b_row3_col4, #T_7a69b_row4_col0, #T_7a69b_row4_col1, #T_7a69b_row4_col2, #T_7a69b_row4_col3, #T_7a69b_row4_col4, #T_7a69b_row5_col0, #T_7a69b_row5_col1, #T_7a69b_row5_col2, #T_7a69b_row5_col3, #T_7a69b_row5_col4, #T_7a69b_row6_col0, #T_7a69b_row6_col1, #T_7a69b_row6_col2, #T_7a69b_row6_col3, #T_7a69b_row6_col4, #T_7a69b_row7_col0, #T_7a69b_row7_col1, #T_7a69b_row7_col2, #T_7a69b_row7_col3, #T_7a69b_row7_col4, #T_7a69b_row8_col0, #T_7a69b_row8_col1, #T_7a69b_row8_col2, #T_7a69b_row8_col3, #T_7a69b_row8_col4, #T_7a69b_row9_col0, #T_7a69b_row9_col1, #T_7a69b_row9_col2, #T_7a69b_row9_col3, #T_7a69b_row9_col4, #T_7a69b_row10_col0, #T_7a69b_row10_col1, #T_7a69b_row10_col2, #T_7a69b_row10_col3, #T_7a69b_row10_col4, #T_7a69b_row11_col0, #T_7a69b_row11_col1, #T_7a69b_row11_col2, #T_7a69b_row11_col3, #T_7a69b_row11_col4, #T_7a69b_row12_col0, #T_7a69b_row12_col1, #T_7a69b_row12_col2, #T_7a69b_row12_col3, #T_7a69b_row12_col4, #T_7a69b_row13_col0, #T_7a69b_row13_col1, #T_7a69b_row13_col2, #T_7a69b_row13_col3, #T_7a69b_row13_col4, #T_7a69b_row14_col0, #T_7a69b_row14_col1, #T_7a69b_row14_col2, #T_7a69b_row14_col3, #T_7a69b_row14_col4, #T_7a69b_row15_col0, #T_7a69b_row15_col1, #T_7a69b_row15_col2, #T_7a69b_row15_col3, #T_7a69b_row15_col4, #T_7a69b_row16_col0, #T_7a69b_row16_col1, #T_7a69b_row16_col2, #T_7a69b_row16_col3, #T_7a69b_row16_col4, #T_7a69b_row17_col0, #T_7a69b_row17_col1, #T_7a69b_row17_col2, #T_7a69b_row17_col3, #T_7a69b_row17_col4, #T_7a69b_row18_col0, #T_7a69b_row18_col1, #T_7a69b_row18_col2, #T_7a69b_row18_col3, #T_7a69b_row18_col4, #T_7a69b_row19_col0, #T_7a69b_row19_col1, #T_7a69b_row19_col2, #T_7a69b_row19_col3, #T_7a69b_row19_col4, #T_7a69b_row20_col0, #T_7a69b_row20_col1, #T_7a69b_row20_col2, #T_7a69b_row20_col3, #T_7a69b_row20_col4, #T_7a69b_row21_col0, #T_7a69b_row21_col1, #T_7a69b_row21_col2, #T_7a69b_row21_col3, #T_7a69b_row21_col4, #T_7a69b_row22_col0, #T_7a69b_row22_col1, #T_7a69b_row22_col2, #T_7a69b_row22_col3, #T_7a69b_row22_col4, #T_7a69b_row23_col0, #T_7a69b_row23_col1, #T_7a69b_row23_col2, #T_7a69b_row23_col3, #T_7a69b_row23_col4, #T_7a69b_row24_col0, #T_7a69b_row24_col1, #T_7a69b_row24_col2, #T_7a69b_row24_col3, #T_7a69b_row24_col4, #T_7a69b_row25_col0, #T_7a69b_row25_col1, #T_7a69b_row25_col2, #T_7a69b_row25_col3, #T_7a69b_row25_col4, #T_7a69b_row26_col0, #T_7a69b_row26_col1, #T_7a69b_row26_col2, #T_7a69b_row26_col3, #T_7a69b_row26_col4, #T_7a69b_row27_col0, #T_7a69b_row27_col1, #T_7a69b_row27_col2, #T_7a69b_row27_col3, #T_7a69b_row27_col4, #T_7a69b_row28_col0, #T_7a69b_row28_col1, #T_7a69b_row28_col2, #T_7a69b_row28_col3, #T_7a69b_row28_col4, #T_7a69b_row29_col0, #T_7a69b_row29_col1, #T_7a69b_row29_col2, #T_7a69b_row29_col3, #T_7a69b_row29_col4, #T_7a69b_row30_col0, #T_7a69b_row30_col1, #T_7a69b_row30_col2, #T_7a69b_row30_col3, #T_7a69b_row30_col4, #T_7a69b_row31_col0, #T_7a69b_row31_col1, #T_7a69b_row31_col2, #T_7a69b_row31_col3, #T_7a69b_row31_col4, #T_7a69b_row32_col0, #T_7a69b_row32_col1, #T_7a69b_row32_col2, #T_7a69b_row32_col3, #T_7a69b_row32_col4, #T_7a69b_row33_col0, #T_7a69b_row33_col1, #T_7a69b_row33_col2, #T_7a69b_row33_col3, #T_7a69b_row33_col4, #T_7a69b_row34_col0, #T_7a69b_row34_col1, #T_7a69b_row34_col2, #T_7a69b_row34_col3, #T_7a69b_row34_col4, #T_7a69b_row35_col0, #T_7a69b_row35_col1, #T_7a69b_row35_col2, #T_7a69b_row35_col3, #T_7a69b_row35_col4, #T_7a69b_row36_col0, #T_7a69b_row36_col1, #T_7a69b_row36_col2, #T_7a69b_row36_col3, #T_7a69b_row36_col4 {
#   text-align: left;
# }
# </style>
# <table id="T_7a69b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a69b_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_7a69b_level0_col1" class="col_heading level0 col1" >bpe</th>
#       <th id="T_7a69b_level0_col2" class="col_heading level0 col2" >lin</th>
#       <th id="T_7a69b_level0_col3" class="col_heading level0 col3" >BPE</th>
#       <th id="T_7a69b_level0_col4" class="col_heading level0 col4" >LIN</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a69b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a69b_row0_col0" class="data row0 col0" >machine</td>
#       <td id="T_7a69b_row0_col1" class="data row0 col1" >machine</td>
#       <td id="T_7a69b_row0_col2" class="data row0 col2" >machine</td>
#       <td id="T_7a69b_row0_col3" class="data row0 col3" >Machine</td>
#       <td id="T_7a69b_row0_col4" class="data row0 col4" >Machine</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a69b_row1_col0" class="data row1 col0" >machines</td>
#       <td id="T_7a69b_row1_col1" class="data row1 col1" >m, ach, ines</td>
#       <td id="T_7a69b_row1_col2" class="data row1 col2" >machine, s</td>
#       <td id="T_7a69b_row1_col3" class="data row1 col3" >Mach, ines</td>
#       <td id="T_7a69b_row1_col4" class="data row1 col4" >Machine, s</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a69b_row2_col0" class="data row2 col0" >machined</td>
#       <td id="T_7a69b_row2_col1" class="data row2 col1" >m, ach, ined</td>
#       <td id="T_7a69b_row2_col2" class="data row2 col2" >machine, d</td>
#       <td id="T_7a69b_row2_col3" class="data row2 col3" >Mach, ined</td>
#       <td id="T_7a69b_row2_col4" class="data row2 col4" >Machine, d</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a69b_row3_col0" class="data row3 col0" >machining</td>
#       <td id="T_7a69b_row3_col1" class="data row3 col1" >m, ach, ining</td>
#       <td id="T_7a69b_row3_col2" class="data row3 col2" >mac, hin, ing</td>
#       <td id="T_7a69b_row3_col3" class="data row3 col3" >Mach, ining</td>
#       <td id="T_7a69b_row3_col4" class="data row3 col4" >Mach, ining</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a69b_row4_col0" class="data row4 col0" >machinion</td>
#       <td id="T_7a69b_row4_col1" class="data row4 col1" >m, ach, inion</td>
#       <td id="T_7a69b_row4_col2" class="data row4 col2" >mac, hin, ion</td>
#       <td id="T_7a69b_row4_col3" class="data row4 col3" >Mach, inion</td>
#       <td id="T_7a69b_row4_col4" class="data row4 col4" >Mach, inion</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a69b_row5_col0" class="data row5 col0" >machinery</td>
#       <td id="T_7a69b_row5_col1" class="data row5 col1" >m, ach, inery</td>
#       <td id="T_7a69b_row5_col2" class="data row5 col2" >machine, ry</td>
#       <td id="T_7a69b_row5_col3" class="data row5 col3" >Mach, inery</td>
#       <td id="T_7a69b_row5_col4" class="data row5 col4" >Machine, ry</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a69b_row6_col0" class="data row6 col0" >machineries</td>
#       <td id="T_7a69b_row6_col1" class="data row6 col1" >m, ach, ineries</td>
#       <td id="T_7a69b_row6_col2" class="data row6 col2" >machine, ries</td>
#       <td id="T_7a69b_row6_col3" class="data row6 col3" >Mach, ineries</td>
#       <td id="T_7a69b_row6_col4" class="data row6 col4" >Machine, ries</td>
#     </tr>
#     <tr>
#       <th id="T_7a69b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a69b_row7_col0" class="data row7 col0" >token</td>
#       <td id="T_7a69b_row7_col1" class="data row7 col1" >token</td>
#       <td id="T_7a69b_row7_col2" class="data row7 col2" >token</td>
#       <td id="T_7a69b_row7_col3" class="data row7 col3" >Token</td>
#       <td id="T_7a6
